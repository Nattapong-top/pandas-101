# %% [markdown]
# Cell 1 — Import Library

# %%
import pandas as pd

# %% [markdown]
# ติดตั้ง openpyxl

# %%
pip install openpyxl

# %% [markdown]
# Cell 2 — โหลดไฟล์ 12 เดือนของป๋า

# %%
file_path = '../datasets/Support_Report_2025.xlsx'
df_all = pd.read_excel(file_path, sheet_name=None)
df_all
# Out:
# {'2025-01':                 ปัญหาที่ได้รับ ผู้แจ้งปัญหา               วิธีการแก้ไข  \
#  0        ตรวจสอบเครื่องมีปัญหา  พนักงานใหม่       ติดตั้งโปรแกรมสำเร็จ
#  1                ลบโปรแกรม wps      CS Team         ลบโปรแกรมเรียบร้อย
#  2    สร้าง printer code ให้ทีม  พนักงานใหม่       ติดตั้งโปรแกรมสำเร็จ
#  3              แก้ network ช้า  พนักงานใหม่           แก้ network แล้ว
#  4       set com ให้พนักงานใหม่    ฝ่ายบัญชี         reset account แล้ว
#  ..                         ...          ...                        ...
#  145           ติดตั้ง software  พนักงานใหม่      ติดตั้ง software แล้ว
#  146        เพิ่มสิทธิ์ scanner  ฝ่ายการตลาด  สร้าง code printer สำเร็จ
#  147     set com ให้พนักงานใหม่  ฝ่ายการตลาด           ติดตั้งเสร็จสิ้น
#  148              reset account    ฝ่ายบุคคล  สร้าง code printer สำเร็จ
#  149     set com ให้พนักงานใหม่      CS Team           แก้ network แล้ว
#
#           Asset tag การเปลี่ยน OA   优先事项            Start 日期            End 日期  \
# ...

# %% [markdown]
# Cell 3 — รวมทุกชีตเข้าด้วยกัน

# %%
import pandas as pd

combined_df = pd.concat(df_all.values(), ignore_index=True)
combined_df.head()
# Out:
#               ปัญหาที่ได้รับ ผู้แจ้งปัญหา          วิธีการแก้ไข  \
# 0      ตรวจสอบเครื่องมีปัญหา  พนักงานใหม่  ติดตั้งโปรแกรมสำเร็จ
# 1              ลบโปรแกรม wps      CS Team    ลบโปรแกรมเรียบร้อย
# 2  สร้าง printer code ให้ทีม  พนักงานใหม่  ติดตั้งโปรแกรมสำเร็จ
# 3            แก้ network ช้า  พนักงานใหม่      แก้ network แล้ว
# 4     set com ให้พนักงานใหม่    ฝ่ายบัญชี    reset account แล้ว
#
#        Asset tag การเปลี่ยน OA  优先事项            Start 日期            End 日期  \
# 0  JTTH/CO/98437         ไม่มี  ด่วน 2025-01-06 12:48:00  2025-01-06 20:48
# 1  JTTH/CO/97254         ไม่มี  ด่วน 2025-01-15 09:37:00  2025-01-15 17:37
# 2  JTTH/CO/93182         ไม่มี  ปกติ 2025-01-13 15:18:00  2025-01-13 22:18
# 3  JTTH/CO/90502            มี  ด่วน 2025-01-09 17:53:00  2025-01-10 01:53
# 4  JTTH/CO/92374            มี  ปกติ 2025-01-19 15:11:00  2025-01-19 19:11
#
#         JOB Location   Dept Status 状态     ผู้ดูแล year_month
# 0  Computer       HQ     HQ    Failed    @jirapat    2025-01
# ...

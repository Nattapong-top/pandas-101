# %% [markdown]
# List to Pandas: ก้าวแรกสู่การจัดการข้อมูลอย่างมืออาชีพ
#
# บท 1 — list basic → pandas Series
#
# พื้นฐาน:
#
# สร้าง list
#
# index
#
# slice
#
# loop
#
# pandas คู่กัน:
#
# สร้าง Series
#
# index แบบมีชื่อ
#
# slice แถว
#
# operations แบบทั้งคอลัมน์
#
# บท 2 — nested list → pandas DataFrame
#
# พื้นฐาน:
#
# list ซ้อน list
#
# เข้าถึง row/col
#
# loop ทุกแถว
#
# pandas คู่กัน:
#
# สร้าง DataFrame
#
# head(), tail()
#
# df["col"], df.loc, df.iloc
#
# ดู structure
#
# บท 3 — dict → DataFrame columns
#
# พื้นฐาน:
#
# key/value
#
# สร้าง dict list
#
# loop dicts
#
# pandas คู่กัน:
#
# column = dict key
#
# update column
#
# rename column
#
# drop column
#
# บท 4 — filter list → filter DataFrame
#
# พื้นฐาน:
#
# [x for x in data if x[2] < 50]
#
#
# pandas คู่กัน:
#
# df[df["RAM"] < 16]
#
#
# หัวใจเดียวกัน → อธิบายให้เห็นแบบโคตรชัด
#
# บท 5 — loop → vectorized (pandas)
#
# พื้นฐาน:
#
# for
#
# if
#
# count
#
# sum
#
# pandas คู่กัน:
#
# df["col"].sum()
#
# df["col"].mean()
#
# df["col"].astype()
#
# apply() (version เบา ๆ)
#
# บท 6 — list of dict → groupby
#
# พื้นฐาน:
#
# loop นับจำนวนด้วย dict
#
# รายกลุ่ม
#
# pandas คู่กัน:
#
# df.groupby("Department").size()
# df.groupby("OS")["RAM"].mean()
#
#
# โคตรทรงพลังแล้วใช้จริงในงานป๋าแน่นอน
#
# บท 7 — combine list → concat/merge
#
# พื้นฐาน:
#
# extend()
#
# zip()
#
# match index
#
# pandas คู่กัน:
#
# concat
#
# merge (เหมือน VLOOKUP / JOIN)
#
# reset_index
#
# บท 8 — write file → export DataFrame
#
# พื้นฐาน:
#
# เปิดไฟล์
#
# เขียนไฟล์
#
# pandas คู่กัน:
#
# df.to_csv(...)
# df.to_excel(...)
#
# จุกทองถามป๋า: อยากเริ่มจากหัวข้อไ

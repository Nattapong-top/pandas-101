# %% [markdown]
# 7) โจทย์ฝึก Dict (ยังไม่เฉลย)
#
# เน้นงานจริงแบบ Pandas
#
# 7.1 ให้ dict ข้อมูลพนักงาน เพิ่มค่า "salary" เข้าไป
#
# logic: เพิ่ม key ใหม่
#
# 7.2 ให้ list ของ dict แล้วหาค่าเฉลี่ยอายุ
#
# logic: loop → sum → count
#
# 7.3 ให้ list ของ dict แล้วดึงรายชื่อพนักงาน dept=“IT”
#
# logic: filter เหมือน Pandas
#
# 7.4 แปลง list ของ dict → dict ของ list
#
# logic: column-driven
#
# 7.5 Merge dict 2 ตัวเข้าด้วยกัน
#
# logic: update()
#
# ทั้งหมดคือ foundation ที่ Pandas ใช้อยู่ทุกวัน
